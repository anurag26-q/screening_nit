# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data=pd.read_csv(r'F:\Screenig BAtch\screening_nit\python\data\data.csv')
titanic=pd.read_csv(r'F:\Screenig BAtch\screening_nit\python\data\titanic_ dataset_final.csv')

# %%
data.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
import ollama
# from datasets import load_dataset

def generate_insights(df_summary):
    prompt=f'analize the following data and provide insights:\n{df_summary}'
    response = ollama.generate(prompt)
    return response
data=generate_insights(titanic)
print(data)
# Out:
# ---------------------------------------------------------------------------
# ResponseError                             Traceback (most recent call last)
# Cell In[8], line 8
#       6     response = ollama.generate(prompt)
#       7     return response
# ----> 8 data=generate_insights(titanic)
#       9 print(data)
#
# Cell In[8], line 6, in generate_insights(df_summary)
#       4 def generate_insights(df_summary):
#       5     prompt=f'analize the following data and provide insights:\n{df_summary}'
# ----> 6     response = ollama.generate(prompt)
#       7     return response
#
# File f:\Screenig BAtch\screening_nit\venv\lib\site-packages\ollama\_client.py:242, in Client.generate(self, model, prompt, suffix, system, template, context, stream, raw, format, images, options, keep_alive)
#     216 def generate(
#     217   self,
#     218   model: str = '',
#    (...)
#     230   keep_alive: Optional[Union[float, str]] = None,
# ...
